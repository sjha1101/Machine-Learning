# %%
#sentiemnt analysis
#pip install nltk
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\atmiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#Continue from the above line of code
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

#Intializing the analyzer
analyzer=SentimentIntensityAnalyzer()
#This line creates an object of the class SentimentIntensityAnalyer,
#it loads the VADER sentiment lexicon (Dictionary of -7500 words,emojis,emonticons,acronyms)
#with pre-assigned sentiment scores.
#Sentences
sentences=[
    "I love this product! It's amzing.",
    "This is wrost experince ever.",
    "This product was okay,not great but not bad either."
]
for text in sentences:
    scores=analyzer.polarity_scores(text)
    print(text,"--->",scores)
#It tells whether the review is positive,negative or neutral and also the compound.
# Out:
# I love this product! It's amzing. ---> {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.6696}
# This is wrost experince ever. ---> {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This product was okay,not great but not bad either. ---> {'neg': 0.0, 'neu': 0.525, 'pos': 0.475, 'compound': 0.745}

# %%
#Reading and plotting the audio data
#pip install li
import librosa
import librosa.display
import matplotlib.pyplot as plt

#load an audio file
audio_file='sample.wav'
y,sr=librosa.load(audio_file)

#plot the waveform of the audio file
plt.figure(figsize=(10,4))
librosa.display.waveshow(y,sr=sr)
plt.title('audio waves')
plt.xlabel('seconds')
plt.ylabel('Amplitude')
plt.show()
