# %%
#contrast effect on gray scale image
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('image.jpg',0)
img1=cv2.equalizeHist(img)

plt.subplot(1,2,1),plt.imshow(img,cmap='gray'),plt.title('source'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1,cmap='gray'),plt.title('Contrast on gray scale'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'Contrast on gray scale'}>,
# ...
#  Text(0.5, 1.0, 'Contrast on gray scale'),
#  <function matplotlib.pyplot.axis(arg: 'tuple[float, float, float, float] | bool | str | None' = None, /, *, emit: 'bool' = True, **kwargs) -> 'tuple[float, float, float, float]'>)

# %%
#Contrast effect on color image
#using global histogram equalization

import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('cat.png')

#convert to YCrCb
ycrcb=cv2.cvtColor(img,cv2.COLOR_BGR2YCrCb)
y,cr,cb=cv2.split(ycrcb)

#Global Histogram equalization 
y_eq=cv2.equalizeHist(y)
ycrcb_eq=cv2.merge([y_eq,cr,cb])
global_eq=cv2.cvtColor(ycrcb_eq,cv2.COLOR_YCrCb2BGR)

plt.figure(figsize=(6,6))

plt.subplot(1,2,1),plt.imshow(img),plt.title('source'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(global_eq),plt.title('Contrast on color image'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'Contrast on color image'}>,
# ...
#  Text(0.5, 1.0, 'Contrast on color image'),
#  (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5)))

# %%
#Contrast effect on color image
#using CLAHE

import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('cat2.png')

#convert to YCrCb
ycrcb=cv2.cvtColor(img,cv2.COLOR_BGR2YCrCb)
y,cr,cb=cv2.split(ycrcb)

clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
y_clahe=clahe.apply(y)
ycrcb_clahe=cv2.merge([y_clahe,cr,cb])
clahe_eq=cv2.cvtColor(ycrcb_clahe,cv2.COLOR_YCrCb2BGR)

plt.figure(figsize=(6,6))

plt.subplot(1,2,1),plt.imshow(img),plt.title('source'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(clahe_eq),plt.title('Contrast on color image'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'Contrast on color image'}>,
# ...
#  Text(0.5, 1.0, 'Contrast on color image'),
#  (np.float64(-0.5), np.float64(359.5), np.float64(359.5), np.float64(-0.5)))
